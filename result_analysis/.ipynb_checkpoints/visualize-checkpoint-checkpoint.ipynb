# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import re

# %% [markdown]
# ## 1 Slow Down

# %%
image_scale = [1, 4, 9, 16]
n_gpu_time = [0.0011,0.0019,0.0034,0.0055]
n_openmp_time = [0.079566,
0.191321,
0.411753,
0.724317
]
n_serial_time = [1.660690,6.626279,14.901165,26.465120]

fig, ax = plt.subplots(figsize=(6,6))
ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(image_scale, n_gpu_time, 'bo-', label=r'GPU')
ax.plot(image_scale, n_openmp_time, 'co-', label=r'OpenMP')
ax.plot(image_scale, n_serial_time, 'go-', label=r'Serial $O(n)$')

ax.set_xlabel("Problem Size(Image Sizes)")
ax.set_ylabel("Time(s)")

ax.set_title("Problem Size vs Time(s) in log coordinate")
plt.grid()
ax.legend()

# %%
# slow down calculation
openmp_index = (np.log(0.724317) - np.log(0.079566)) / (np.log(16) - np.log(1)) - 1
gpu_index = (np.log(0.0055) - np.log(0.0011)) / (np.log(16) - np.log(1)) - 1
serial_index = (np.log(26.384604) - np.log(1.658905)) / (np.log(16) - np.log(1)) - 1
print(openmp_index,
gpu_index,
serial_index)
# Out:
# -0.20340068535099065 -0.41951797627815934 -0.0021517111901595554

# %%
rgba2gray = np.array([0.010936, 0.014840,  0.018960, 0.025472])
post_pro_with_max = np.array([0.008574, 0.032461, 0.072081, 0.128096])
find_max = np.array([0.002182, 0.009086, 0.021112, 0.037780])
conv3 = np.array([0.054521, 0.122779, 0.272671, 0.485060])
gray2rgba = np.array([ 0.005057, 0.021085, 0.047885,  0.085534])

post_pro = post_pro_with_max - find_max
post_pro

import pandas as pd
import matplotlib.pyplot as plt

Problem_size=["image","image 4x","image 9x","image 16x"]
data={
    "Conversion(RGBA to Grayscale)":rgba2gray,
    "Edge Detection":conv3,
    "Get Globel Max":find_max,
    "Grayscale Stretch":post_pro,
    "Conversion(Grayscale to RGBA)":gray2rgba,
}

df=pd.DataFrame(data,index=Problem_size)

df.plot(kind="bar",stacked=True,figsize=(5,5))
plt.legend(loc="lower left",bbox_to_anchor=(0,1.0))
plt.xlabel("Image Size")
plt.ylabel("runtime(s) of each part")
plt.show()
data
# Out:
# {'Conversion(RGBA to Grayscale)': array([0.010936, 0.01484 , 0.01896 , 0.025472]),
#  'Edge Detection': array([0.054521, 0.122779, 0.272671, 0.48506 ]),
#  'Get Globel Max': array([0.002182, 0.009086, 0.021112, 0.03778 ]),
#  'Grayscale Stretch': array([0.006392, 0.023375, 0.050969, 0.090316]),
#  'Conversion(Grayscale to RGBA)': array([0.005057, 0.021085, 0.047885, 0.085534])}

# %%
# Get ratio
all_time = rgba2gray + post_pro + find_max + conv3 + gray2rgba
rgba2gray = rgba2gray / all_time
post_pro = post_pro / all_time
find_max = find_max / all_time
conv3 = conv3 / all_time
gray2rgba = gray2rgba / all_time

import pandas as pd
import matplotlib.pyplot as plt

Problem_size=["image","image 4x","image 9x","image 16x"]
data={
    "Conversion(RGBA to Grayscale)":rgba2gray,
    "Edge Detection":conv3,
    "Get Globel Max":find_max,
    "Grayscale Stretch":post_pro,
    "Conversion(Grayscale to RGBA)":gray2rgba,
}

df=pd.DataFrame(data,index=Problem_size)

df.plot(kind="bar",stacked=True,figsize=(5,5))
plt.legend(loc="lower left",bbox_to_anchor=(0,1.0))
plt.xlabel("Image Size")
plt.ylabel("runtime percentage of each part")
plt.show()
data
# Out:
# {'Conversion(RGBA to Grayscale)': array([0.13827635, 0.07762927, 0.04606448, 0.03517445]),
#  'Edge Detection': array([0.68937133, 0.64226715, 0.66247081, 0.6698225 ]),
#  'Get Globel Max': array([0.02758952, 0.04752962, 0.05129289, 0.05217065]),
#  'Grayscale Stretch': array([0.08082136, 0.12227657, 0.12383229, 0.12471795]),
#  'Conversion(Grayscale to RGBA)': array([0.06394143, 0.11029739, 0.11633953, 0.11811446])}

# %%
import pandas as pd
import matplotlib.pyplot as plt

rgba2gray = np.array([0.917733, 0.219124, 0.024989, 0.00008816])
post_pro_with_max = np.array([6.030402, 1.481743, 0.133631, 0.00028704])
find_max = np.array([0.038141,  0.036373, 0.037403, 0.00015642])
conv3 = np.array([19.178391, 5.300208, 0.500514, 0.00010365])
gray2rgba = np.array([1.239235, 0.311985, 0.079763,  0])

post_pro = post_pro_with_max - find_max
post_pro

Problem_size=["Serial","OpenMP(4 threads)","OpenMP(4 threads)","CUDA"]
data={
    "Conversion(RGBA to Grayscale)":rgba2gray,
    "Edge Detection":conv3,
    "Get Globel Max":find_max,
    "Grayscale Stretch":post_pro,
    "Conversion(Grayscale to RGBA)":gray2rgba,
}

df=pd.DataFrame(data,index=Problem_size)

df.plot(kind="bar",stacked=True,figsize=(5,5))
plt.legend(loc="lower left",bbox_to_anchor=(1.0,0))
plt.xlabel("Image Size")
plt.ylabel("runtime(s) of each part")
plt.xticks(rotation=45)
plt.show()
data
# Out:
# {'Conversion(RGBA to Grayscale)': array([9.17733e-01, 2.19124e-01, 2.49890e-02, 8.81600e-05]),
#  'Edge Detection': array([1.9178391e+01, 5.3002080e+00, 5.0051400e-01, 1.0365000e-04]),
#  'Get Globel Max': array([0.038141  , 0.036373  , 0.037403  , 0.00015642]),
#  'Grayscale Stretch': array([5.992261e+00, 1.445370e+00, 9.622800e-02, 1.306200e-04]),
#  'Conversion(Grayscale to RGBA)': array([1.239235, 0.311985, 0.079763, 0.      ])}

# %%
# Get ratio
all_time = rgba2gray + post_pro + find_max + conv3 + gray2rgba
rgba2gray = rgba2gray / all_time
post_pro = post_pro / all_time
find_max = find_max / all_time
conv3 = conv3 / all_time
gray2rgba = gray2rgba / all_time

Problem_size=["Serial","OpenMP(4 threads)","OpenMP(4 threads)","CUDA"]
data={
    "Conversion(RGBA to Grayscale)":rgba2gray,
    "Edge Detection":conv3,
    "Get Globel Max":find_max,
    "Grayscale Stretch":post_pro,
    "Conversion(Grayscale to RGBA)":gray2rgba,
}

df=pd.DataFrame(data,index=Problem_size)

df.plot(kind="bar",stacked=True,figsize=(5,5))
plt.legend(loc="lower left",bbox_to_anchor=(1.0,0))
plt.xlabel("Image Size")
plt.ylabel("percentage of runtime of each part")
plt.xticks(rotation=45)
plt.show()
data
# Out:
# {'Conversion(RGBA to Grayscale)': array([0.03353581, 0.02996338, 0.03381933, 0.18410776]),
#  'Edge Detection': array([0.70081702, 0.72475927, 0.67737993, 0.21645609]),
#  'Get Globel Max': array([0.00139375, 0.0049737 , 0.05062005, 0.32665762]),
#  'Grayscale Stretch': array([0.21896928, 0.1976423 , 0.13023195, 0.27277853]),
#  'Conversion(Grayscale to RGBA)': array([0.04528414, 0.04266135, 0.10794874, 0.        ])}

# %% [markdown]
# ## 2 Strong sclaing

# %%
import numpy as np
threads_num = np.array([4,8,16,32,64])
strong_time = np.array([7.332812,
3.966220,
2.101034,
1.163144,
0.757214])
serial = 26.3846

eff = serial / (threads_num * strong_time) * 100
eff
# Out:
# array([89.9538949 , 83.15411147, 78.48694976, 70.88707417, 54.44423571])

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(['4','8','16','32','64'], strong_time, marker='o', color='royalblue', label='OpenMP')
ax.plot(['4','8','16','32','64'], [7.3332, 3.666, 1.833, 0.9165, 0.4582], 'g--', label='Reference(Slope=-1)')
ax.set_xlabel("Threads")
ax.set_ylabel("Runtime (sec)")

ax.set_title("log-log-scale Strong Scaling(OpenMP)")
ax.set_yscale('log')
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(['4','8','16','32','64'], eff, marker='o', color='royalblue')
ax.set_xlabel("Threads")
ax.set_ylabel("Percentage (%)")

ax.set_title("Strong Scaling Efficiency (OpenMP)")
plt.grid()
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 2 Weak Scaling

# %%
weak_time = np.array([0.458033,
0.534656,
0.602405,
0.750227,
])
idea_time = [0.458033,0.458033,0.458033,0.458033]
fig, ax = plt.subplots(figsize=(6,6))
ax.plot([1,4,9,16], weak_time, marker='o', color='royalblue', label='OpenMP(4-task-per-image)')
ax.plot([1,4,9,16], idea_time, 'g--', label='Reference(Horizontal)')

ax.set_xlabel("Image Scale")
ax.set_ylabel("Runtime(sec)")
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_title("log-log-scale Weak Scaling(OpenMP)")
plt.grid()
ax.legend()

# %% [markdown]
# # 3 Serial Slow down

# %%
serial_test_time = np.array([1.660690,
6.626279,
14.901165,
26.465120,
])
idea_serial_test_time = [1.660690,6.64276,14.94621,26.57104]
fig, ax = plt.subplots(figsize=(6,6))
ax.plot([1,4,9,16], serial_test_time, marker='o', color='royalblue', label='Serial(Slope=0.998)')
ax.plot([1,4,9,16], idea_serial_test_time, 'g--', label='Reference(Slope=1)')

ax.set_xlabel("Image Scale")
ax.set_ylabel("Runtime(sec)")
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_title("log-log-scale Serial Slowdown")
plt.grid()
ax.legend()

# %%
(np.log(26.384604) - np.log(1.658905)) / (np.log(16) - np.log(1))
# Out:
# 0.9978482888098404
